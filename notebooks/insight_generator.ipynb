# %%
import pandas as pd
import json

INPUT_FILE = "../data/transactions_patterns.csv"
OUTPUT_FILE = "../data/transaction_insights.json"

df = pd.read_csv(INPUT_FILE, parse_dates=["datetime"])

insights = []

# %%
def build_spending_anomaly(row):
    return {
        "transaction_id": row["transaction_id"],
        "insight_type": "SPENDING_ANOMALY",
        "severity": "HIGH" if abs(row["amount_zscore"]) >= 3 else "MEDIUM",
        "facts": {
            "category": row["category"],
            "amount": row["amount"],
            "usual_category_avg": row["category_avg_amount"],
            "zscore": row["amount_zscore"],
            "merchant": row["merchant"]
        }
    }

def build_time_behavior(row):
    return {
        "transaction_id": row["transaction_id"],
        "insight_type": "TIME_BEHAVIOR_SHIFT",
        "severity": "MEDIUM",
        "facts": {
            "time_bucket": row["time_bucket"],
            "is_weekend": bool(row["is_weekend"]),
            "hour": row["hour"]
        }
    }


def build_merchant_change(row):
    return {
        "transaction_id": row["transaction_id"],
        "insight_type": "MERCHANT_RARITY",
        "severity": "LOW",
        "facts": {
            "merchant": row["merchant"],
            "merchant_txn_count": row["merchant_txn_count"],
            "merchant_avg_amount": row["merchant_avg_amount"]
        }
    }

# %%
for _, row in df.iterrows():
    flags = row["flags"].split("|")

    if "HIGH_AMOUNT" in flags or "LOW_AMOUNT" in flags:
        insights.append(build_spending_anomaly(row))

    if "LATE_NIGHT_WEEKDAY" in flags:
        insights.append(build_time_behavior(row))

    if "RARE_MERCHANT" in flags:
        insights.append(build_merchant_change(row))

# %%
print(insights)
# Out:
# [{'transaction_id': 'TXN000010', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 23}}, {'transaction_id': 'TXN000070', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 23}}, {'transaction_id': 'TXN000137', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 22}}, {'transaction_id': 'TXN000145', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Food', 'amount': 146.98, 'usual_category_avg': 71.84, 'zscore': 2.19, 'merchant': 'MCDONALDS'}}, {'transaction_id': 'TXN000180', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Food', 'amount': 154.55, 'usual_category_avg': 71.84, 'zscore': 2.41, 'merchant': 'LOCAL CAFE'}}, {'transaction_id': 'TXN000239', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Food', 'amount': 141.64, 'usual_category_avg': 71.84, 'zscore': 2.03, 'merchant': 'GRAB*FOOD'}}, {'transaction_id': 'TXN000259', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Shopping', 'amount': 563.12, 'usual_category_avg': 287.1, 'zscore': 2.0, 'merchant': 'LAZADA'}}, {'transaction_id': 'TXN000272', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 23}}, {'transaction_id': 'TXN000286', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 22}}, {'transaction_id': 'TXN000338', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Food', 'amount': 144.39, 'usual_category_avg': 71.84, 'zscore': 2.11, 'merchant': 'LOCAL CAFE'}}, {'transaction_id': 'TXN000445', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Food', 'amount': 143.67, 'usual_category_avg': 71.84, 'zscore': 2.09, 'merchant': 'KFC'}}, {'transaction_id': 'TXN000516', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Shopping', 'amount': 636.29, 'usual_category_avg': 287.1, 'zscore': 2.53, 'merchant': 'SHOPEE'}}, {'transaction_id': 'TXN000538', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 22}}, {'transaction_id': 'TXN000636', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Food', 'amount': 146.65, 'usual_category_avg': 71.84, 'zscore': 2.18, 'merchant': 'KFC'}}, {'transaction_id': 'TXN000669', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Shopping', 'amount': 601.47, 'usual_category_avg': 287.1, 'zscore': 2.28, 'merchant': 'SHOPEE'}}, {'transaction_id': 'TXN000705', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 23}}, {'transaction_id': 'TXN000729', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 23}}, {'transaction_id': 'TXN000745', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 22}}, {'transaction_id': 'TXN000760', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 22}}, {'transaction_id': 'TXN000780', 'insight_type': 'TIME_BEHAVIOR_SHIFT', 'severity': 'MEDIUM', 'facts': {'time_bucket': 'LATE_NIGHT', 'is_weekend': False, 'hour': 23}}, {'transaction_id': 'TXN000813', 'insight_type': 'SPENDING_ANOMALY', 'severity': 'MEDIUM', 'facts': {'category': 'Food', 'amount': 148.51, 'usual_category_avg': 71.84, 'zscore': 2.23, 'merchant': 'MCDONALDS'}}, {'transaction_id': 'TXN000853', 'insight_type': 'TIME_BEHAVIOR_SHIFT', ...

# %%
with open(OUTPUT_FILE, "w") as f:
    json.dump(insights, f, indent=2)

print(f"Generated {len(insights)} insight signals → {OUTPUT_FILE}")
# Out:
# Generated 23 insight signals → ../data/transaction_insights.json
