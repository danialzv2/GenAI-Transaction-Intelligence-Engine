# %%
import pandas as pd

INPUT_FILE = "../data/transactions_features.csv"
OUTPUT_FILE = "../data/transactions_patterns.csv"

df = pd.read_csv(INPUT_FILE, parse_dates=["datetime"])

# %%
# INITIALIZE FLAGS & REASONS
df["flags"] = ""
df["reasons"] = ""

# %%
def add_flag_reason(row, flag, reason):
    if row["flags"]:
        row["flags"] += f"|{flag}"
        row["reasons"] += f" | {reason}"
    else:
        row["flags"] = flag
        row["reasons"] = reason
    return row

for idx, row in df.iterrows():

    # High amount anomaly
    if row["amount_zscore"] >= 2.0:
        df.loc[idx] = add_flag_reason(
            row,
            "HIGH_AMOUNT",
            "Transaction amount is significantly higher than your usual category spending"
        )

    # Low amount anomaly
    if row["amount_zscore"] <= -2.0:
        df.loc[idx] = add_flag_reason(
            row,
            "LOW_AMOUNT",
            "Transaction amount is significantly lower than your usual category spending"
        )

    # Late night weekday
    if row["time_bucket"] == "LATE_NIGHT" and not row["is_weekend"]:
        df.loc[idx] = add_flag_reason(
            row,
            "LATE_NIGHT_WEEKDAY",
            "Transaction occurred late at night on a weekday"
        )

    # New or rare merchant
    if row["merchant_txn_count"] <= 2:
        df.loc[idx] = add_flag_reason(
            row,
            "RARE_MERCHANT",
            "This merchant is new or rarely used in your transaction history"
        )

df.head()
# Out:
#   transaction_id user_id            datetime  amount merchant  category  \
# 0      TXN000003    U001 2025-01-01 12:20:00  372.27   LAZADA  Shopping
# 1      TXN000001    U001 2025-01-01 14:11:00  357.83   UNIQLO  Shopping
# 2      TXN000002    U001 2025-01-01 15:41:00   83.12    SETEL      Fuel
# 3      TXN000004    U001 2025-01-01 18:03:00  423.52   SHOPEE  Shopping
# 4      TXN000008    U001 2025-01-02 12:49:00  185.36    LOTUS   Grocery
#
#       channel payment_type       location  hour  ...  is_weekend  time_bucket  \
# 0    E-WALLET        DEBIT   Kuala Lumpur    12  ...       False    AFTERNOON
# 1    E-WALLET        DEBIT  Petaling Jaya    14  ...       False    AFTERNOON
# 2  DEBIT CARD        DEBIT  Petaling Jaya    15  ...       False    AFTERNOON
# 3  DEBIT CARD        DEBIT  Petaling Jaya    18  ...       False      EVENING
# 4    E-WALLET        DEBIT      Shah Alam    12  ...       False    AFTERNOON
#
#   category_avg_amount  category_std_amount  category_txn_count  \
# 0              287.10               137.94                 177
# 1              287.10               137.94                 177
# 2               83.21                22.89                 142
# 3              287.10               137.94                 177
# 4              141.85                61.78                 177
#
#    merchant_avg_amount  merchant_txn_count  amount_zscore  flags reasons
# 0               299.90                  51           0.62
# 1               296.04                  35           0.51
# 2                85.28                  42          -0.00
# 3               252.19                  45           0.99
# 4               149.89                  47           0.70
#
# [5 rows x 21 columns]

# %%
df_filter_flags = df[df["amount_zscore"]>=2]
df_filter_flags.head()
# Out:
#     transaction_id user_id            datetime  amount    merchant  category  \
# 143      TXN000145    U001 2025-03-02 10:39:00  146.98   MCDONALDS      Food
# 177      TXN000180    U001 2025-03-15 10:08:00  154.55  LOCAL CAFE      Food
# 238      TXN000239    U001 2025-04-06 15:25:00  141.64   GRAB*FOOD      Food
# 257      TXN000259    U001 2025-04-12 16:16:00  563.12      LAZADA  Shopping
# 339      TXN000338    U001 2025-05-18 19:08:00  144.39  LOCAL CAFE      Food
#
#         channel payment_type       location  hour  ...  is_weekend  \
# 143    E-WALLET        DEBIT  Petaling Jaya    10  ...        True
# 177  DEBIT CARD        DEBIT      Shah Alam    10  ...        True
# 238  DEBIT CARD        DEBIT  Petaling Jaya    15  ...        True
# 257  DEBIT CARD        DEBIT  Petaling Jaya    16  ...        True
# 339  DEBIT CARD        DEBIT      Shah Alam    19  ...        True
#
#      time_bucket category_avg_amount  category_std_amount  category_txn_count  \
# 143      MORNING               71.84                34.34                 263
# 177      MORNING               71.84                34.34                 263
# 238    AFTERNOON               71.84                34.34                 263
# 257    AFTERNOON              287.10               137.94                 177
# 339      EVENING               71.84                34.34                 263
#
#      merchant_avg_amount  merchant_txn_count  amount_zscore        flags  \
# 143                65.96                  57           2.19  HIGH_AMOUNT
# 177                75.05                  62           2.41  HIGH_AMOUNT
# 238                71.35                  45           2.03  HIGH_AMOUNT
# 257               299.90                  51           2.00  HIGH_AMOUNT
# 339                75.05                  62           2.11  HIGH_AMOUNT
#
#                                                reasons
# 143  Transaction amount is significantly higher tha...
# 177  Transaction amount is significantly higher tha...
# 238  Transaction amount is significantly higher tha...
# 257  Transaction amount is significantly higher tha...
# 339  Transaction amount is significantly higher tha...
#
# [5 rows x 21 columns]

# %%
df["flags"] = df["flags"].replace("", "NORMAL")
df["reasons"] = df["reasons"].replace("", "No unusual spending behavior detected")
df.head()
# Out:
#   transaction_id user_id            datetime  amount merchant  category  \
# 0      TXN000003    U001 2025-01-01 12:20:00  372.27   LAZADA  Shopping
# 1      TXN000001    U001 2025-01-01 14:11:00  357.83   UNIQLO  Shopping
# 2      TXN000002    U001 2025-01-01 15:41:00   83.12    SETEL      Fuel
# 3      TXN000004    U001 2025-01-01 18:03:00  423.52   SHOPEE  Shopping
# 4      TXN000008    U001 2025-01-02 12:49:00  185.36    LOTUS   Grocery
#
#       channel payment_type       location  hour  ...  is_weekend  time_bucket  \
# 0    E-WALLET        DEBIT   Kuala Lumpur    12  ...       False    AFTERNOON
# 1    E-WALLET        DEBIT  Petaling Jaya    14  ...       False    AFTERNOON
# 2  DEBIT CARD        DEBIT  Petaling Jaya    15  ...       False    AFTERNOON
# 3  DEBIT CARD        DEBIT  Petaling Jaya    18  ...       False      EVENING
# 4    E-WALLET        DEBIT      Shah Alam    12  ...       False    AFTERNOON
#
#   category_avg_amount  category_std_amount  category_txn_count  \
# 0              287.10               137.94                 177
# 1              287.10               137.94                 177
# 2               83.21                22.89                 142
# 3              287.10               137.94                 177
# 4              141.85                61.78                 177
#
#    merchant_avg_amount  merchant_txn_count  amount_zscore   flags  \
# 0               299.90                  51           0.62  NORMAL
# 1               296.04                  35           0.51  NORMAL
# 2                85.28                  42          -0.00  NORMAL
# 3               252.19                  45           0.99  NORMAL
# 4               149.89                  47           0.70  NORMAL
#
#                                  reasons
# 0  No unusual spending behavior detected
# 1  No unusual spending behavior detected
# 2  No unusual spending behavior detected
# 3  No unusual spending behavior detected
# 4  No unusual spending behavior detected
#
# [5 rows x 21 columns]

# %%
df = df.sort_values("datetime")
df.to_csv(OUTPUT_FILE, index=False)

print(f"Pattern detection completed → {OUTPUT_FILE}")
# Out:
# Pattern detection completed → ../data/transactions_patterns.csv
